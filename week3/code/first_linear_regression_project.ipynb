# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # importing nesesarry models for the project

# %%
df = pd.read_csv("/home/ziad/GitHub/Machine-Learning-journey/week3/data/Housing_Data (2).csv")

# %% [markdown]
# # load the data from csv file (Housing_Data (2).csv)
# # and contain it in variable

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Drop rows with null values

# %%
df = df.drop("Address", axis=1)

# %% [markdown]
# # remove the address column becouse we dont need it

# %%
x = df.drop("Price", axis=1)

# %% [markdown]
# # create X wich contain every feature

# %%
y=df["Price"]

# %%
scaler=StandardScaler

# %%
x_norm=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %% [markdown]
# # normalaize the data in x to make it more accurite

# %%
y=y.values.reshape(-1,1)
y_norm=pd.DataFrame(scaler.fit_transform(y),colums="price")

# %% [markdown]
# # reshape y to make it 1d matrix
# # normalize y

# %%
print(x)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...
