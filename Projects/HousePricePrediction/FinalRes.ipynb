# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,PolynomialFeatures
import seaborn as sns 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("cleaned.csv")

# %%
correlation_matrix = df.corr()

# %%
#ast column is the target variable
target_variable_name = df.columns[-1]

# Get the correlation of each feature with the target variable
correlation_with_target = correlation_matrix[target_variable_name].drop(target_variable_name)

# Sort correlations by absolute value
sorted_correlation_with_target = correlation_with_target.abs().sort_values(ascending=False)

# %%
# Select the top 10 most correlated features
top_features = sorted_correlation_with_target.head(30).index
new_df=df[top_features]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OverallQual   1460 non-null   int64
#  1   GrLivArea     1460 non-null   int64
#  2   GarageCars    1460 non-null   int64
#  3   GarageArea    1460 non-null   int64
#  4   ExterQual     1460 non-null   int64
#  5   BsmtQual      1460 non-null   int64
#  6   TotalBsmtSF   1460 non-null   int64
#  7   1stFlrSF      1460 non-null   int64
#  8   KitchenQual   1460 non-null   int64
#  9   FullBath      1460 non-null   int64
#  10  GarageFinish  1460 non-null   int64
#  11  YearBuilt     1460 non-null   int64
#  12  TotRmsAbvGrd  1460 non-null   int64
#  13  YearRemodAdd  1460 non-null   int64
#  14  Fireplaces    1460 non-null   int64
#  15  MasVnrArea    1460 non-null   int64
#  16  FireplaceQu   1460 non-null   int64
#  17  LotArea       1460 non-null   int64
# ...

# %%
Y=df["SalePrice"]

# %%
Y=pd.DataFrame(Y)

# %%
model=LinearRegression()

# %%
scaler=MinMaxScaler()

# %%
poly=PolynomialFeatures(degree=1)

# %%
new_df=poly.fit_transform(new_df)

# %%
new_df.shape
# Out:
# (1460, 31)

# %%
new_df_scaled=scaler.fit_transform(new_df)

# %%
Y_scaled=scaler.fit_transform(Y)

# %%
model.fit(new_df_scaled,Y_scaled)
# Out:
# LinearRegression()

# %%
Y_pre=model.predict(new_df_scaled)

# %%
Y_pre = scaler.inverse_transform(Y_pre)

# %%
mse=mean_squared_error(Y,Y_pre)/2

# %%
r2=r2_score(Y,Y_pre)

# %%
print("\nMean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
# Out:
# Mean Squared Error (MSE): 526563302.66370517
# R-squared (R2) Score: 0.8330169798661353

# %% [markdown]
# ##
#
# with 1 degree in polynomial regression
#
#
#
# Mean Squared Error (MSE): 526563302.66370517
#
#
# R-squared (R2) Score: 0.8330169798661353
#
# ##
#
# ##
# with 2 degree in polynomial regression
#
# Mean Squared Error (MSE): 185454416.22640982
#
# R-squared (R2) Score: 0.941188954182729
#
#
# ##
#
# ##
# with 3 degree in polynomial regression
#
# Mean Squared Error (MSE): 9631.84931582204
#
# R-squared (R2) Score: 0.9999969455613786
# ##
# ##
#
#
# with 4 degree in polynomial regression
#
# Mean Squared Error (MSE): 9631.849340913714
#
#
# R-squared (R2) Score: 0.9999969455613708
#
# ##
