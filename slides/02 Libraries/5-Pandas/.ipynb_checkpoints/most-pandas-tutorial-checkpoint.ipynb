# %%
import pandas as pd

# %%
lst = [10, 7, 25]
row = pd.Series(lst)
# Use index keys as: 0, 1, 2, 3, etc
row[1]
# Out:
# 7

# %%
dct = {'x' : 10, 'y': 7, 'z': 25}
row = pd.Series(dct)
row['y']
# Out:
# 7

# %%
data_dct_col_value = {
    # Column name: Column values list
  'cars'    : ["BMW", "Volvo", "Ford"],
  'passings': [3,       7,      2]
}

# DataFrame is like 2D array: rows x cols
data = pd.DataFrame(data_dct_col_value)

data
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
data['cars']
# Out:
# 0      BMW
# 1    Volvo
# 2     Ford
# Name: cars, dtype: object

# %%
row = data.loc[1]   # row idx 1
row
# Out:
# cars        Volvo
# passings        7
# Name: 1, dtype: object

# %%
data = pd.DataFrame(data_dct_col_value, index = ["ex0", "ex1", "ex2"])
data
# Out:
#       cars  passings
# ex0    BMW         3
# ex1  Volvo         7
# ex2   Ford         2

# %%
row = data.loc['ex1']
row
# Out:
# cars        Volvo
# passings        7
# Name: ex1, dtype: object

# %%
data.shape
# Out:
# (3, 2)

# %%
df = pd.DataFrame({'month': [1, 4, 7, 10],
                   'year': [2012, 2014, 2013, 2014],
                   'sale': [55, 40, 84, 31]})
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
# first n rows. Default is 5. Good for initial validation
df.head(2)
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40

# %%
new_df = df.set_index('month')
new_df
# Out:
#        year  sale
# month
# 1      2012    55
# 4      2014    40
# 7      2013    84
# 10     2014    31

# %%
data.columns 
# No month any more as a column. It is now index
# Out:
# Index(['cars', 'passings'], dtype='object')

# %%
new_df['month'])  # KeyError

# %%
new_df['year']
# Out:
# month
# 1     2012
# 4     2014
# 7     2013
# 10    2014
# Name: year, dtype: int64

# %%
# inplace=True: change it. Don't create a new one
df.set_index(['year', 'month'], inplace=True)
df
# Out:
#             sale
# year month
# 2012 1        55
# 2014 4        40
# 2013 7        84
# 2014 10       31

# %%
df.loc[2014]
# Out:
#        sale
# month
# 4        40
# 10       31

# %%
# Use slicing to get all rows or cols
df.loc[2014, :]
# Out:
#        sale
# month
# 4        40
# 10       31

# %%
df.loc[2014, 4]
# Out:
# sale    40
# Name: (2014, 4), dtype: int64

# %%
# Load a comma separated text file (CSV file) into a DataFrame
df = pd.read_csv('panda_background.csv')
df
# Out:
#     Name             Email  Phone Number            Address
# 0      A    most@gmail.com  123-456-7890     Canada Burnaby
# 1      B  ziad@example.com  123-456-7890        USA Seattle
# 2      C    most@gmail.com  123-456-7890   Canada " Burnaby
# 3      D  ziad@example.com  123-456-7890       USA, Seattle
# 4      E    most@gmail.com  123-456-7890  Canada "" Burnaby
# ..   ...               ...           ...                ...
# 116   Dl  ziad@example.com  123-456-7890        USA Seattle
# 117   El    most@gmail.com  123-456-7890     Canada Burnaby
# 118   Fl  ziad@example.com  123-456-7890        USA Seattle
# 119   Gl    most@gmail.com  123-456-7890     Canada Burnaby
# 120   Hl  ziad@example.com  123-456-7890        USA Seattle
#
# [121 rows x 4 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 9999
df
# Out:
#     Name             Email  Phone Number            Address
# 0      A    most@gmail.com  123-456-7890     Canada Burnaby
# 1      B  ziad@example.com  123-456-7890        USA Seattle
# 2      C    most@gmail.com  123-456-7890   Canada " Burnaby
# 3      D  ziad@example.com  123-456-7890       USA, Seattle
# 4      E    most@gmail.com  123-456-7890  Canada "" Burnaby
# 5      F  ziad@example.com  123-456-7890        USA Seattle
# 6      G    most@gmail.com  123-456-7890     Canada Burnaby
# 7      H  ziad@example.com  123-456-7890        USA Seattle
# 8      A    most@gmail.com  123-456-7890     Canada Burnaby
# 9      B  ziad@example.com  123-456-7890        USA Seattle
# 10     C    most@gmail.com  123-456-7890     Canada Burnaby
# 11     D  ziad@example.com  123-456-7890        USA Seattle
# 12     E    most@gmail.com  123-456-7890     Canada Burnaby
# 13     F  ziad@example.com  123-456-7890        USA Seattle
# 14     G    most@gmail.com  123-456-7890     Canada Burnaby
# ...

# %%
data_dct_col_value = {
  'A'    : [10, None, 20],
  'B': [1, 2, 3],
  'X': [None, 5, None]
}
df = pd.DataFrame(data_dct_col_value)
df
# Out:
#       A  B    X
# 0  10.0  1  NaN
# 1   NaN  2  5.0
# 2  20.0  3  NaN

# %%
df.median()
# Out:
# A    15.0
# B     2.0
# X     5.0
# dtype: float64

# %%
df = df.fillna(df.median())
df
# Out:
#       A  B    X
# 0  10.0  1  5.0
# 1  15.0  2  5.0
# 2  20.0  3  5.0

# %%
data = df.to_numpy()
data
# Out:
# array([[10.,  1.,  5.],
#        [15.,  2.,  5.],
#        [20.,  3.,  5.]])
