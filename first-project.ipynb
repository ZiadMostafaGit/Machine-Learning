# %%
import numpy as np

# %%
name=input("enter your name ")

# %%
print (f"hallo {name} good to see you")

firts=np.array([2003,3002,2001,2000])
print(firts)
# Out:
# hallo ziad good to see you
# [2003 3002 2001 2000]
